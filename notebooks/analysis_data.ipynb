# %%
path = '../data/weather_data/weather.json'
import pandas as pd
import json

# %%
with open(path) as f:
  data = json.load(f)

df = pd.json_normalize(data)
df.head()
# Out:
#                                              weather      base  visibility  \
# 0  [{'id': 800, 'main': 'Clear', 'description': '...  stations       10000
#
#            dt  timezone       id       name  cod  coord.lon  coord.lat  ...  \
# 0  1777203276    -10800  3448439  São Paulo  200   -46.6361   -23.5475  ...
#
#    main.grnd_level  wind.speed  wind.deg  wind.gust  clouds.all  sys.type  \
# 0              926        2.24       348       2.68           0         1
#
#    sys.id  sys.country  sys.sunrise  sys.sunset
# 0    8394           BR   1777195472  1777236231
#
# [1 rows x 27 columns]
